# %% [markdown]
# ## Import Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Replace this with your actual path and filename
file_path = r'C:\Users\nolia\OneDrive\Desktop\spotify-data-visualization\spotify-2023.csv'

# Load the dataset
df = pd.read_csv(file_path, encoding='ISO-8859-1')

# Preview the data
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df.head()
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %% [markdown]
# ## Data Cleaning

# %%
### clean 'streams' column 
df['streams_clean'] = df['streams'].str.replace(',', '', regex=False)
df = df[df['streams_clean'].str.isnumeric()].copy()
df['streams'] = df['streams_clean'].astype('int64')
df.drop(columns='streams_clean', inplace=True)

# %%
### check for duplicates
print(f'Duplicates before drop: {df.duplicated().sum()}')

# drop if any
df = df.drop_duplicates()
# Out:
# Duplicates before drop: 0

# %%
# Check nulls
nulls = df.isnull().sum()
print(nulls[nulls > 0])
# Out:
# in_shazam_charts    50
# key                 95
# dtype: int64

# %%
### clean shazam column
# convert to string and remove commas
df['in_shazam_charts'] = df['in_shazam_charts'].astype(str).str.replace(',', '', regex=False)

# replace 'nan' string with '0'
df['in_shazam_charts'] = df['in_shazam_charts'].replace('nan', '0')

# convert to integer
df['in_shazam_charts'] = df['in_shazam_charts'].astype('int64')

# %%
### clean key column by dropping nans, since they are an important musical property and should not be guessed
df = df.dropna(subset=['key'])

# %%
df.isnull().sum()
# Out:
# track_name              0
# artist(s)_name          0
# artist_count            0
# released_year           0
# released_month          0
# released_day            0
# in_spotify_playlists    0
# in_spotify_charts       0
# streams                 0
# in_apple_playlists      0
# in_apple_charts         0
# in_deezer_playlists     0
# in_deezer_charts        0
# in_shazam_charts        0
# bpm                     0
# key                     0
# mode                    0
# danceability_%          0
# valence_%               0
# energy_%                0
# acousticness_%          0
# instrumentalness_%      0
# liveness_%              0
# speechiness_%           0
# dtype: int64

# %%
### check all numeric columns are actually numeric
df.dtypes
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                  int64
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists     object
# in_deezer_charts         int64
# in_shazam_charts         int64
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %%
### clean deezer column
# convert to string and remove commas
df['in_deezer_playlists'] = df['in_deezer_playlists'].astype(str).str.replace(',', '', regex=False)

# replace 'nan' string with '0'
df['in_deezer_playlists'] = df['in_deezer_playlists'].replace('nan', '0')

# convert to integer
df['in_deezer_playlists'] = df['in_deezer_playlists'].astype('int64')

# %%
df.dtypes
# Out:
# track_name              object
# artist(s)_name          object
# artist_count             int64
# released_year            int64
# released_month           int64
# released_day             int64
# in_spotify_playlists     int64
# in_spotify_charts        int64
# streams                  int64
# in_apple_playlists       int64
# in_apple_charts          int64
# in_deezer_playlists      int64
# in_deezer_charts         int64
# in_shazam_charts         int64
# bpm                      int64
# key                     object
# mode                    object
# danceability_%           int64
# valence_%                int64
# energy_%                 int64
# acousticness_%           int64
# instrumentalness_%       int64
# liveness_%               int64
# speechiness_%            int64
# dtype: object

# %%
### check for unique values
for col in ['key', 'mode', 'released_year', 'artist_count']:
    print(f'\n{col}:\n', df[col].unique())
# Out:
# key:
#  ['B' 'C#' 'F' 'A' 'D' 'F#' 'G#' 'G' 'E' 'A#' 'D#']
#
# mode:
#  ['Major' 'Minor']
#
# released_year:
#  [2023 2019 2022 2014 2018 2017 2020 2016 2012 1999 2008 1975 2021 2015
#  2011 2004 1985 2002 2013 2010 1983 1992 1984 2000 1997 1995 2003 1973
#  1930 1994 1958 1957 1963 1959 1970 1971 1946 1979 1950 1942 1986 2005
#  1991 1996 1998 1982 1987]
#
# artist_count:
#  [2 1 3 5 4 6 8 7]

# %%
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 857 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            857 non-null    object
#  1   artist(s)_name        857 non-null    object
#  2   artist_count          857 non-null    int64
#  3   released_year         857 non-null    int64
#  4   released_month        857 non-null    int64
#  5   released_day          857 non-null    int64
#  6   in_spotify_playlists  857 non-null    int64
#  7   in_spotify_charts     857 non-null    int64
#  8   streams               857 non-null    int64
#  9   in_apple_playlists    857 non-null    int64
#  10  in_apple_charts       857 non-null    int64
#  11  in_deezer_playlists   857 non-null    int64
#  12  in_deezer_charts      857 non-null    int64
#  13  in_shazam_charts      857 non-null    int64
#  14  bpm                   857 non-null    int64
# ...

# %% [markdown]
# ## Visualizations

# %%
# Set style
sns.set(style='whitegrid', palette='muted')

# Features to analyze
features = ['danceability_%', 'energy_%', 'valence_%', 'acousticness_%']

# Plot each feature against streams
for feature in features:
    plt.figure(figsize=(8, 5))
    sns.regplot(data=df, x=feature, y='streams', scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
    plt.title(f'Streams vs {feature}', fontsize=14)
    plt.xlabel(feature.replace('_', ' ').title())
    plt.ylabel('Streams')
    plt.tight_layout()
    plt.show()

# %%
# list of platforms to analyze
placement_cols = ['in_spotify_playlists', 'in_apple_playlists', 'in_shazam_charts']

# loop through each platform and plot average streams
for col in placement_cols:
    plt.figure(figsize=(6, 4))
    
    # group and average
    avg_streams = df.groupby(df[col] > 0)['streams'].mean().reset_index()
    avg_streams[col] = avg_streams[col].map({True: f'{col} > 0', False: f'{col} = 0'})
    
    # bar plot
    sns.barplot(data=avg_streams, x=col, y='streams')
    plt.title(f'Average Streams vs {col.replace("_", " ").title()} Presence')
    plt.ylabel('Average Streams')
    plt.xlabel('Playlist/Chart Presence')
    plt.tight_layout()
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# list of playlist/chart columns
placement_cols = ['in_spotify_playlists', 'in_apple_playlists', 'in_shazam_charts']

for col in placement_cols:
    plt.figure(figsize=(12, 5))

    # plot count of songs
    plt.subplot(1, 2, 1)
    counts = (df[col] > 0).value_counts()
    counts.index = counts.index.map(lambda x: f'{col} > 0' if x else f'{col} = 0')
    sns.barplot(x=counts.index, y=counts.values)
    plt.title(f'Number of Songs by {col.replace("_", " ").title()} Presence')
    plt.ylabel('Count')
    plt.xlabel('')

    # plot stream distribution
    plt.subplot(1, 2, 2)
    df['placement_group'] = df[col].apply(lambda x: f'{col} > 0' if x > 0 else f'{col} = 0')
    sns.boxplot(data=df, x='placement_group', y='streams')
    plt.title(f'Streams Distribution by {col.replace("_", " ").title()}')
    plt.ylabel('Streams')
    plt.xlabel('')
    
    plt.tight_layout()
    plt.show()

# %%
# create a new column counting how many platforms each song appears on
playlist_cols = ['in_spotify_playlists', 'in_apple_playlists', 'in_shazam_charts']
df['playlist_count'] = df[playlist_cols].gt(0).sum(axis=1)

# visualize boxplot of streams by number of playlists
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x='playlist_count', y='streams')
plt.title('Streams vs Number of Playlist/Chart Features')
plt.xlabel('Number of Platforms (Spotify, Apple, Shazam)')
plt.ylabel('Streams')
plt.tight_layout()
plt.show()
